# %% [markdown]
# # lec06-dev

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import seaborn as sns

from matplotlib_inline.backend_inline import set_matplotlib_formats
set_matplotlib_formats("svg")

# DSC 80 preferred styles
pio.templates["dsc80"] = go.layout.Template(
    layout=dict(
        margin=dict(l=30, r=30, t=30, b=30),
        autosize=True,
        xaxis=dict(showgrid=True),
        yaxis=dict(showgrid=True),
        title=dict(x=0.5, xanchor="center"),
    )
)
pio.templates.default = "simple_white+dsc80"

import warnings
warnings.simplefilter('ignore')

import datetime

plt.rcParams['axes.axisbelow'] = True

# %%
# !ls ../
# Out:
# dev      imgs     lec06.md

# %%
plt.figure(figsize=(6, 6), dpi=200)
plt.grid(color='#eee')
plt.arrow(0, 0, 5, 3, color='#007aff', linewidth=4, length_includes_head=True, head_width=1/16)
plt.annotate(r"$\vec{v}$", (4.5, 3), color='#007aff', size=20)
plt.xlim(0, 6)
plt.xticks(size=16)
plt.ylim(0, 6)
plt.yticks(size=16)
plt.savefig('../imgs/v-only.png', bbox_inches='tight')

# %%
plt.figure(figsize=(6, 6), dpi=200)
plt.grid(color='#eee')
plt.arrow(0, 0, 5, 3, color='#007aff', linewidth=4, length_includes_head=True, head_width=1/16)
plt.annotate(r"$\vec{v}$", (4.5, 3), color='#007aff', size=20)

plt.arrow(0, 0, 2, 4, color='purple', linewidth=4, length_includes_head=True, head_width=1/16)
plt.annotate(r"$\vec{u}$", (1.35, 3.6), color='purple', size=20)

plt.xlim(0, 6)
plt.xticks(size=16)
plt.ylim(0, 6)
plt.yticks(size=16)
# plt.savefig('../imgs/u-and-v.png', bbox_inches='tight')

# %%
plt.figure(figsize=(6, 6), dpi=200)
plt.grid(color='#eee')
plt.arrow(0, 0, 5, 3, color='#007aff', linewidth=4, length_includes_head=True, head_width=1/16)
plt.annotate(r"$\vec{v}$", (4, 3), color='#007aff', size=14)

plt.arrow(0, 0, 2, 4, color='purple', linewidth=4, length_includes_head=True, head_width=1/16)
plt.annotate(r"$\vec{u}$", (1, 3.6), color='purple', size=14)

plt.xlim(-10, 10)
plt.xticks(range(-10, 12, 2), size=16)
plt.ylim(-10, 10)
plt.yticks(range(-10, 12, 2), size=16)
# plt.savefig('../imgs/u-and-v-range.png', bbox_inches='tight')

# %%
plt.figure(figsize=(6, 6), dpi=200)
plt.grid(color='#eee')
plt.arrow(0, 0, -2, -4, color='#007aff', linewidth=4, length_includes_head=True, head_width=1/16)
plt.annotate(r"$\vec{v}$", (-2.5, -3.5), color='#007aff', size=20)

plt.arrow(0, 0, 4, 1, color='purple', linewidth=4, length_includes_head=True, head_width=1/16)
plt.annotate(r"$\vec{u}$", (3.8, 1.3), color='purple', size=20)

plt.annotate(r"$\theta$", (0.16, -0.6), size=20)

plt.xlim(-5, 5)
plt.xticks(range(-4, 5), size=16)
plt.ylim(-5, 5)
plt.yticks(range(-4, 5), size=16);
plt.savefig('../imgs/example-theta.png', transparent=True, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(6, 6), dpi=200, frameon='off')

ax = fig.add_subplot(1, 1, 1)
# plt.grid(color='#eee')

plt.arrow(0, 0, 8, 6, color='#007aff', linewidth=4, length_includes_head=True, head_width=1/16)
plt.annotate(r"$\vec{x}$", (8.2, 5.8), color='#007aff', size=20)

plt.arrow(0, 0, 2, 6, color='orange', linewidth=4, length_includes_head=True, head_width=1/16)
plt.annotate(r"$\vec{y}$", (1.3, 5.8), color='orange', size=20)


plt.xlim(0, 10)
plt.xticks([])
plt.ylim(0, 7.5)
plt.yticks([])
plt.box('off')
# plt.savefig('../imgs/u-and-v-range.png', bbox_inches='tight')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
plt.savefig('../imgs/project-y-on-x.png', bbox_inches='tight')
